# %% [markdown]
# ### Two Sum (Easy)
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# You can return the answer in any order.
#
#
#
# Example 1:
#
# Input: nums = [2,7,11,15], target = 9
# Output: [0,1]
# Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
# Example 2:
#
# Input: nums = [3,2,4], target = 6
# Output: [1,2]
# Example 3:
#
# Input: nums = [3,3], target = 6
# Output: [0,1]

# %%
from typing import List

# %%
dicty = {
    'a':1,
    'b': 2,
    'c': 3
}
if 5 in dicty.values():
    print("T")

# %%
my_dict = {'apple': 1, 'banana': 2, 'cherry': 2}
target_value = 2

# Returns 'banana' (stops at the first match)
key = next((k for k, v in my_dict.items() if v == target_value), None)
print(key)
# Out:
# banana

# %%
a = [0,1,2,3]
h={}
for i in range(len(a)):
    h[i] = a[i]

print(h)
# Out:
# {0: 0, 1: 1, 2: 2, 3: 3}

# %%
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        # make a hashmap of index:values
        hsmp = {}
        for i in range(len(nums)):
            hsmp[i] = nums[i]

        for i in range(len(nums)):
            complement = target - nums[i]
            if complement in hsmp.values():
                key_comp = next(k for k,v in hsmp.items() if v==complement)
                if(key_comp!=i):
                    return[i, key_comp]

# %%
s = Solution()
result = s.twoSum([3,3],6)
print(result)
# Out:
# [1, 0]
