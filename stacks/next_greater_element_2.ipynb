# %% [markdown]
# ### Next Greater Element - II (Medium)
#
# Given a circular integer array nums (i.e., the next element of nums[nums.length - 1] is nums[0]), return the next greater number for every element in nums.
#
# The next greater number of a number x is the first greater number to its traversing-order next in the array, which means you could search circularly to find its next greater number. If it doesn't exist, return -1 for this number.
#
#
#
# Example 1:
#
# Input: nums = [1,2,1]
# Output: [2,-1,2]
# Explanation: The first 1's next greater number is 2;
# The number 2 can't find next greater number.
# The second 1's next greater number needs to search circularly, which is also 2.
# Example 2:
#
# Input: nums = [1,2,3,4,3]
# Output: [2,3,4,-1,4]
#
#
# Constraints:
#
# 1 <= nums.length <= 104
# -109 <= nums[i] <= 109

# %%
from typing import List

# %%
monotonic_stack : list[tuple[int, int]] = []
monotonic_stack.append((1,2))
print(monotonic_stack)
monotonic_stack.pop()
print(monotonic_stack)
# Out:
# [(1, 2)]
# []

# %%
        mono_stack: list[tuple[int, int]] = []
        result = [-1] * len(nums)
        for i, cur in enumerate(nums):
            while mono_stack and cur > mono_stack[-1][0]:
                val, ind = mono_stack.pop()
                result[ind] = cur
            mono_stack.append((cur, i))
        for cur in nums:
            while cur > mono_stack[-1][0]:
                val, ind = mono_stack.pop()
                result[ind] = cur
        return result

# %%
class Solution:
    def nextGreaterElements(self, nums: list[int]) -> list[int]:

        # create an empty monotonic stack of (val, index)
        monotonic_stack : list[tuple[int, int]] = []

        # create an output array
        output = [-1]*len(nums)

        # we add in the list if current element is smaller than top of the mono stack
        # we keep popping from the stack until the top element becomes greater than the current value

        for idx, val in enumerate(nums):

            # popping condition
            while monotonic_stack and monotonic_stack[-1][0] < val:
                popped_val, popped_idx = monotonic_stack.pop()
                output[popped_idx] = val

            # appending condition
            monotonic_stack.append((val, idx))

        # second round since it is a circular array
        for i in nums:
            while i > monotonic_stack[-1][0]:
                popped_val, popped_idx = monotonic_stack.pop()
                output[popped_idx] = i

        return output
